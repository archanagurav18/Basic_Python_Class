# %% [markdown]
# #if_elif_else

# %%
number = float(input('enter a number'))
if number > 0 :
    print('The number {number} is positive')
elif number < 0:
    print('The number {number} is negative')
else:
    print('The number is zero')
# Out:
# enter a number 5
# The number {number} is positive

# %%
number = float(input('enter a number'))
if number > 0 :
    print('The number {number} is positive')
elif number < 0:
    print('The number {number} is negative')
else:
    print('The number is zero')
# Out:
# enter a number -3
# The number {number} is negative

# %%
number = float(input('enter a number'))
if number > 0 :
    print('The number {number} is positive')
elif number < 0:
    print('The number {number} is negative')
else:
    print('The number is zero')
# Out:
# enter a number 0
# The number is zero

# %%
number = float(input('enter a number'))
if number > 0 :
    print('The number {number} is positive')
elif number < 0:
    print('The number {number} is negative')
else:
    print('The number is zero')
# Out:
# enter a number kjjh
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 number = float(input('enter a number'))
#       2 if number > 0 :
#       3     print('The number {number} is positive')
#
# ValueError: could not convert string to float: 'kjjh'

# %%
N = float(input('enter a number'))
if N%5 ==0:
    print('divisible by 5')
else :
    print('not divisble by 5')
# Out:
# enter a number 20
# divisible by 5

# %%
N = float(input('enter a number'))
if N%5 ==0:
    print('divisible by 5')
else :
    print('not divisble by 5')
# Out:
# enter a number 34
# not divisble by 5

# %%
age=65
if age >= 60 :
    print('Senior Citizen')
else :
    print('not Senior Citizen')
# Out:
# Senior Citizen

# %%
age=55
if age >= 60 :
    print('Senior Citizen')
else :
    print('not Senior Citizen')
# Out:
# not Senior Citizen

# %%
x =float(input('Enter a number to check even or odd'))
if x%2 == 0 :
    print('Even')
else :
    print('Odd')
# Out:
# Enter a number to check even or odd 5
# Odd

# %%
x =float(input('Enter a number to check even or odd'))
if x%2 == 0 :
    print('Even')
else :
    print('Odd')
# Out:
# Enter a number to check even or odd 1586
# Even

# %%
name1 = input('enter a name')
name2 = input('enter a name')
if name1==name2 :
    print('same')
else :
    print('not same')
# Out:
# enter a name sham
# enter a name sham
# same

# %%
name1 = input('enter a name')
name2 = input('enter a name')
if name1==name2 :
    print('same')
else :
    print('not same')
# Out:
# enter a name sham
# enter a name ram
# not same

# %%
marks = float(input('Enter u r marks'))
if marks>=90 :
    print('Grade A')
elif  90>marks<70 :
    print('Grade B')
elif  69>marks<40 :
    print('Grade C')
else :
    print('fail')
# Out:
# Enter u r marks 98
# Grade A

# %%
marks = float(input('Enter u r marks'))
if marks>=90 :
    print('Grade A')
elif  marks > 70 and marks <90:
    print('Grade B')
elif  marks >40 and marks <70 :
    print('Grade C')
else :
    print('fail')
# Out:
# Enter u r marks 58
# Grade C

# %%
marks = float(input('Enter u r marks'))
if marks>=90 :
    print('Grade A')
elif  marks > 70 and marks <90:
    print('Grade B')
elif  marks >40 and marks <70 :
    print('Grade C')
else :
    print('fail')
# Out:
# Enter u r marks 78
# Grade B

# %%
marks = float(input('Enter u r marks'))
if marks>=90 :
    print('Grade A')
elif  marks > 70 and marks <90:
    print('Grade B')
elif  marks >40 and marks <70 :
    print('Grade C')
else :
    print('fail')
# Out:
# Enter u r marks 35
# fail

# %%
traffic =input('Enter signal')
if traffic=='red':
    print('Stop')
elif traffic=='Yellow':
    print('wait')
elif traffic=='green':
    print('go')
else :
    print('wrong input')
# Out:
# Enter signal red
# Stop

# %%
traffic =input('Enter signal')
if traffic=='red':
    print('Stop')
elif traffic=='yellow':
    print('wait')
elif traffic=='green':
    print('go')
else :
    print('wrong input')
# Out:
# Enter signal yellow
# wait

# %%
traffic =input('Enter signal')
if traffic=='red':
    print('Stop')
elif traffic=='Yellow':
    print('wait')
elif traffic=='green':
    print('go')
else :
    print('wrong input')
# Out:
# Enter signal jhkj
# wrong input

# %%
traffic =input('Enter signal')
if traffic=='red':
    print('Stop')
elif traffic=='Yellow':
    print('wait')
elif traffic=='green':
    print('go')
else :
    print('wrong input')
# Out:
# Enter signal green
# go

# %%
##Find the greatest of three numbers using elif

# %%
a =float(input('enter number 1'))
b =float(input('enter number 2'))
c =float(input('enter number 3'))
if b < a > c :
    print('a is greatest number')
elif c < b > a :
    print('b is greatest number')
else :
    print('c is greatest number')
# Out:
# enter number 1 75
# enter number 2 45
# enter number 3 12
# a is greatest number

# %%
a =float(input('enter number 1'))
b =float(input('enter number 2'))
c =float(input('enter number 3'))
if b < a > c :
    print('a is greatest number')
elif c < b > a :
    print('b is greatest number')
else :
    print('c is greatest number')
# Out:
# enter number 1 52
# enter number 2 78
# enter number 3 90
# c is greatest number

# %%
a =float(input('enter number 1'))
b =float(input('enter number 2'))
c =float(input('enter number 3'))
if b < a > c :
    print('a is greatest number')
elif c < b > a :
    print('b is greatest number')
else :
    print('c is greatest number')
# Out:
# enter number 1 20
# enter number 2 45
# enter number 3 31
# b is greatest number

# %%
a =float(input('enter number 1'))
b =float(input('enter number 2'))
c =float(input('enter number 3'))
if b < a > c :
    print('a is greatest number')
elif c < b > a :
    print('b is greatest number')
elif b < c > a : 
    print('c is greatest number')
else :
    print('same number entered')
# Out:
# enter number 1 2
# enter number 2 2
# enter number 3 2
# same number entered

# %%
a =float(input('enter number 1'))
b =float(input('enter number 2'))
c =float(input('enter number 3'))
if b < a > c :
    print('a is greatest number')
elif c < b > a :
    print('b is greatest number')
elif b < c > a : 
    print('c is greatest number')
else :
    print('same number entered')
# Out:
# enter number 1 45
# enter number 2 74
# enter number 3 89
# c is greatest number

# %%
a =input("enter name") 
length = (len(a))
if length < 5 :
    print('short')
elif length >=5 and length <15:
    print('perferct')
else :
    print('too long')
# Out:
# enter name archana
# perferct

# %%
a =input("enter name") 
length = (len(a))
if length < 5 :
    print('short')
elif length >=5 and length <15:
    print('perferct')
else :
    print('too long')
# Out:
# enter name sham
# short

# %%
a =input("enter name") 
length = (len(a))
if length < 5 :
    print('short')
elif length >=5 and length <15:
    print('perferct')
else :
    print('too long')
# Out:
# enter name archanashamradhaatharvnikhil
# too long
