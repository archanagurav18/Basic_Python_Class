# %% [markdown]
# # Variables

# %%
a=5

# %%
a
# Out:
# 5

# %%
b=(5)

# %%
b
# Out:
# 5

# %%
number = 5864

# %%
number
# Out:
# 5864

# %%
number is 154
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\HP\AppData\Local\Temp\ipykernel_3368\1820257517.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   number is 154
# False

# %%
number is = 458
# Out:
#   Cell In[12], line 1
#     number is = 458
#               ^
# SyntaxError: invalid syntax

# %%
number_is = 598

# %%
number_is
# Out:
# 598

# %%
name = 'Welcome'

# %%
name
# Out:
# 'Welcome'

# %%
a1 = 'Basic python online class'

# %%
a1
# Out:
# 'Basic python online class'

# %%
8 = 'Hello World'
# Out:
#   Cell In[19], line 1
#     8 = 'Hello World'
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
x = 'Hello World'

# %%
x
# Out:
# 'Hello World'

# %%
x1 = 'Basic Python'

# %%
x1
# Out:
# 'Basic Python'

# %%
y2 = 'Machine Learning'

# %%
y2
# Out:
# 'Machine Learning'

# %%
b@ = 'Deep Learning'
# Out:
#   Cell In[26], line 1
#     b@ = 'Deep Learning'
#        ^
# SyntaxError: invalid syntax

# %%
b@ = 7
# Out:
#   Cell In[27], line 1
#     b@ = 7
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Operations

# %%
54 + 54 # int + int
# Out:
# 108

# %%
62 - 42 # int - int
# Out:
# 20

# %%
25 + 12.5  # int + float
# Out:
# 37.5

# %%
15.5 + 42.6 # float + flaot
# Out:
# 58.1

# %%
200 + 'hello'  # int + str
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 200 + 'hello'  # int + str
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
548.15  + 'Python'  # float + str
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 548.15  + 'Python'  # float + str
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
15 + 58 + 47
# Out:
# 120

# %%
85 + 12.5 + 41 + 34.9
# Out:
# 173.4

# %%
'Basic' + 'Python' # str + str
# Out:
# 'BasicPython'

# %%
'Basic' + ' ' + 'Python'
# Out:
# 'Basic Python'

# %% [markdown]
# # Typecasting

# %%
'12'
# Out:
# '12'

# %%
type('12')
# Out:
# str

# %%
int('12') #str + str
# Out:
# 12

# %%
type(12)
# Out:
# int

# %%
int('p')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 int('p')
#
# ValueError: invalid literal for int() with base 10: 'p'

# %%
num = 785

# %%
type(num)
# Out:
# int

# %%
num = '854'

# %%
type(num)
# Out:
# str

# %%
int(5.65)
# Out:
# 5

# %%
str(457)
# Out:
# '457'

# %%
float(2530.256)
# Out:
# 2530.256

# %%
float(458)
# Out:
# 458.0

# %%
int(2254.45)
# Out:
# 2254

# %%
round (45.25)
# Out:
# 45

# %%
round (5.5)
# Out:
# 6
