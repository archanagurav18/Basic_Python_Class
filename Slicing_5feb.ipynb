# %%
## Slicing Assignment

# %%
l = [10,20,30,40,50,60,70,80]

# %%
l[2:5]
# Out:
# [30, 40, 50]

# %%
l[:4]
# Out:
# [10, 20, 30, 40]

# %%
l[5:]
# Out:
# [60, 70, 80]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l[:-1]
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
l[::-1]
# Out:
# [80, 70, 60, 50, 40, 30, 20, 10]

# %%
l[::2]
# Out:
# [10, 30, 50, 70]

# %%
l[-4:-1]
# Out:
# [50, 60, 70]

# %%
l[6:1:-2]
# Out:
# [70, 50, 30]

# %%
l[5:8]
# Out:
# [60, 70, 80]

# %%
### Nested List

# %%
nested =[1,2,[100,200,[300,400]],5]

# %%
nested[2]
# Out:
# [100, 200, [300, 400]]

# %%
nested[2][1]
# Out:
# 200

# %%
nested[2][2][1]
# Out:
# 400

# %%
nested[2][1]=250

# %%
nested
# Out:
# [1, 2, [100, 250, [300, 400]], 5]

# %%
nested[2]
# Out:
# [100, 250, [300, 400]]

# %%
nested[2][:2]
# Out:
# [100, 250]

# %%
### advanced and Mixed Concepts

# %%
data=[[1,2,3],[4,5,6],[7,8,9]]

# %%
data[1]
# Out:
# [4, 5, 6]

# %%
data[1][1:3]
# Out:
# [5, 6]

# %%
data[2][2:3]
# Out:
# [9]

# %%
data[-1][-1]
# Out:
# 9

# %%
x=[1,2,3]

# %%
x.append([4,5])

# %%
x
# Out:
# [1, 2, 3, [4, 5]]

# %%
x.extend([4,5])

# %%
x
# Out:
# [1, 2, 3, [4, 5], 4, 5]

# %%
z=[10,20,50,76,89,56,87,90]

# %%
z[-3::-1]
# Out:
# [56, 89, 76, 50, 20, 10]

# %%
q=[1,2,3,4,5]

# %%
q[1:4]
# Out:
# [2, 3, 4]

# %%
q[1:4][::-1]
# Out:
# [4, 3, 2]

# %%
a=['hi',1,2,3,4,5]

# %%
a[0:3]
# Out:
# ['hi', 1, 2]
