# %% [markdown]
# # FILE HANDLINE

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E8ED-B1CD
#
#  Directory of C:\Users\HP\Basic_Python\Advance Python
#
# 31-03-2026  07:57    <DIR>          .
# 31-03-2026  07:57    <DIR>          ..
# 31-03-2026  07:57    <DIR>          .ipynb_checkpoints
# 27-03-2026  10:51            28,630 18_day_Oop_26march.ipynb
# 27-03-2026  15:27            13,254 19_day_oop_27march.ipynb
# 31-03-2026  07:56               337 20_day_filehandline_30march.ipynb
#                3 File(s)         42,221 bytes
#                3 Dir(s)  53,825,175,552 bytes free

# %%
f = open('test.txt','r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 f = open('test.txt','r')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
f = open('test.txt','w')

# %%
f.write("this is test file.welcome to python world")
# Out:
# 41

# %%
f.close()

# %%
f = open('test.txt','r')

# %%
f.read()
# Out:
# 'this is test file.welcome to python world'

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'this is test file.welcome to python world'

# %%
f.seek(7)
# Out:
# 7

# %%
f.read()
# Out:
# ' test file.welcome to python world'

# %%
f.write('Hello')
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 f.write('Hello')
#
# UnsupportedOperation: not writable

# %%
f.close()

# %%
f = open('test.txt','r+')

# %%
f.read()
# Out:
# 'this is test file.welcome to python world'

# %%
f.write('this is updated in test file ')
# Out:
# 29

# %%
f.read()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'this is test file.welcome to python worldthis is updated in test file '

# %%
f.close()

# %%
f =open('Agentic_AI.txt','w')

# %%
f.write("""Agentic AI refers to autonomous systems that use LLMs to pursue high-level goals, making decisions and taking multi-step actions with limited human supervision. \n Unlike reactive AI, Agentic AI uses planning, memory, and external tools (APIs, databases) to perform tasks, such as automating supply chains or organizing complex projects""")
# Out:
# 335

# %%
f.close()

# %%
f = open('Agentic_AI.txt','r+')

# %%
f.read()
# Out:
# 'Agentic AI refers to autonomous systems that use LLMs to pursue high-level goals, making decisions and taking multi-step actions with limited human supervision. \n Unlike reactive AI, Agentic AI uses planning, memory, and external tools (APIs, databases) to perform tasks, such as automating supply chains or organizing complex projects'

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'Agentic AI refers to autonomous systems that use LLMs to pursue high-level goals, making decisions and taking multi-step actions with limited human supervision. \n Unlike reactive AI, Agentic AI uses planning, memory, and external tools (APIs, databases) to perform tasks, such as automating supply chains or organizing complex projects'

# %%
f.readline()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# ''

# %%
f.readline()
# Out:
# ' Unlike reactive AI, Agentic AI uses planning, memory, and external tools (APIs, databases) to perform tasks, such as automating supply chains or organizing complex projects'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readlines()
# Out:
# ['Agentic AI refers to autonomous systems that use LLMs to pursue high-level goals, making decisions and taking multi-step actions with limited human supervision. \n',
#  ' Unlike reactive AI, Agentic AI uses planning, memory, and external tools (APIs, databases) to perform tasks, such as automating supply chains or organizing complex projects']

# %%
f.seek(0)
# Out:
# 0

# %%
for ln in f.readlines():
    print(ln)
# Out:
# Agentic AI refers to autonomous systems that use LLMs to pursue high-level goals, making decisions and taking multi-step actions with limited human supervision.
#
#  Unlike reactive AI, Agentic AI uses planning, memory, and external tools (APIs, databases) to perform tasks, such as automating supply chains or organizing complex projects

# %%
f.seek(0)
# Out:
# 0

# %%
l = []
for ln in f.readlines():
    l.append(ln.split(' '))

# %%
l
# Out:
# [['Agentic',
#   'AI',
#   'refers',
#   'to',
#   'autonomous',
#   'systems',
#   'that',
#   'use',
#   'LLMs',
#   'to',
#   'pursue',
#   'high-level',
#   'goals,',
#   'making',
#   'decisions',
#   'and',
#   'taking',
#   'multi-step',
#   'actions',
#   'with',
#   'limited',
#   'human',
#   'supervision.',
#   '\n'],
#  ['',
#   'Unlike',
#   'reactive',
#   'AI,',
#   'Agentic',
#   'AI',
#   'uses',
#   'planning,',
#   'memory,',
#   'and',
#   'external',
#   'tools',
#   '(APIs,',
#   'databases)',
#   'to',
#   'perform',
#   'tasks,',
#   'such',
#   'as',
#   'automating',
#   'supply',
#   'chains',
#   'or',
#   'organizing',
#   'complex',
#   'projects']]

# %%
f.seek(0)
# Out:
# 0

# %%
l2 = []

# %%
for char in f.readline():
    l2.append(char)

# %%
l2
# Out:
# ['A',
#  'g',
#  'e',
#  'n',
#  't',
#  'i',
#  'c',
#  ' ',
#  'A',
#  'I',
#  ' ',
#  'r',
#  'e',
#  'f',
#  'e',
#  'r',
#  's',
#  ' ',
#  't',
#  'o',
#  ' ',
#  'a',
#  'u',
#  't',
#  'o',
#  'n',
#  'o',
#  'm',
#  'o',
#  'u',
#  's',
#  ' ',
#  's',
#  'y',
#  's',
#  't',
#  'e',
#  'm',
#  's',
#  ' ',
#  't',
#  'h',
#  'a',
#  't',
#  ' ',
#  'u',
#  's',
#  'e',
#  ' ',
#  'L',
#  'L',
#  'M',
#  's',
#  ' ',
#  't',
#  'o',
#  ' ',
#  'p',
#  'u',
#  'r',
#  's',
#  'u',
#  'e',
#  ' ',
#  'h',
#  'i',
#  'g',
#  'h',
#  '-',
#  'l',
#  'e',
#  'v',
#  'e',
#  'l',
#  ' ',
#  'g',
#  'o',
#  'a',
#  'l',
#  's',
#  ',',
#  ' ',
#  'm',
#  'a',
#  'k',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'd',
#  'e',
#  'c',
#  'i',
#  's',
#  'i',
#  'o',
#  'n',
#  's',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  't',
#  'a',
#  'k',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'm',
#  'u',
#  'l',
#  't',
#  'i',
#  '-',
#  's',
#  't',
#  'e',
#  'p',
#  ' ',
#  'a',
#  'c',
#  't',
#  'i',
# ...

# %%
f.close()

# %%
f = open('test.txt','r+')

# %%
f.read()
# Out:
# 'this is test file.welcome to python worldthis is updated in test file '

# %%
f.write('next text added in test file')
# Out:
# 28

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'this is test file.welcome to python worldthis is updated in test file next text added in test filePYTHONPYTH'

# %%
f.write('PYTHon')
# Out:
# 6

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'this is test file.welcome to python worldthis is updated in test file next text added in test filePYTHONPYTHPYTHon'

# %%
f.close()

# %%
f = open('base.py','w')
