# %%
try:
    num = int(input('Number'))
    result = 10/num
except ValueError:
    print('Invalid input')
except ZeroDivisionError:
    print('Cannot devide by zero')
# Out:
# Number 10

# %%
try:
    num = int(input('Number'))
    result = 10/num
except ValueError:
    print('Invalid input')
except ZeroDivisionError:
    print('Cannot devide by zero')
# Out:
# Number 0
# Cannot devide by zero

# %%
try:
    num = int(input('Number'))
    result = 10/num
except ValueError:
    print('Invalid input')
except ZeroDivisionError:
    print('Cannot devide by zero')
# Out:
# Number as
# Invalid input

# %%
try:
    num = int(input('Enter a num'))
except ValueError: #if 
    print('Invalid input')
else:
    print('You have entered', num)
# Out:
# Enter a num 10
# You have entered 10

# %%
try:
    num = int(input('Enter a num'))
except ValueError: #if 
    print('Invalid input')
else:
    print('You have entered', num)
# Out:
# Enter a num asd
# Invalid input

# %%
try:
    open('testfile.txt') 
except FileNotFoundError:
    print('File not found')
finally:
    print('Code completed')
# Out:
# File not found
# Code completed

# %%
try:
    password = input('Enter password to login')
    if password != 'python':
        raise ValueError('You have entered Wrong password')
except ValueError as e:
    print(e)
# Out:
# Enter password to login python

# %%
data = ['10','20','30','abc','40','50']

# %%
data
# Out:
# ['10', '20', '30', 'abc', '40', '50']

# %%
for a in data:
    try:
        num = int(a)
        print(num, type(num))
    except ValueError:
        print('Invalid data type to conv into int', a)
# Out:
# 10 <class 'int'>
# 20 <class 'int'>
# 30 <class 'int'>
# Invalid data type to conv into int abc
# 40 <class 'int'>
# 50 <class 'int'>

# %%
import logging

# %%
logging.basicConfig(level = logging.INFO)
logging.info('Project strated')
# Out:
# INFO:root:Project strated

# %%
import logging
logging.basicConfig(level=logging.DEBUG)

logging.debug('DEBUG logging')
logging.info('Info logging')
logging.warning('Warning logging')
logging.error('Error logging')
logging.critical('Critical logging')
# Out:
# INFO:root:Info logging
# WARNING:root:Warning logging
# ERROR:root:Error logging
# CRITICAL:root:Critical logging

# %%
import logging
logging.basicConfig(level=logging.ERROR)

try:
    x = 25/0
except ZeroDivisionError:
    logging.error('Cannot divide by zero')
# Out:
# ERROR:root:Cannot divide by zero

# %%
import logging
logging.basicConfig(level=logging.ERROR)

try:
    x = 50/0
except Exception as e:
    logging.error('Error occurs: %s', e)
# Out:
# ERROR:root:Error occurs: division by zero

# %%
import logging 
logging.basicConfig(filename='app.log', level=logging.INFO)

logging.info('Project started')
try:
    x = 45/0
except Exception as e:
    logging.error('Error occurs: %s', e)
# Out:
# INFO:root:Project started
# ERROR:root:Error occurs: division by zero

# %%
logging.shutdown()

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E8ED-B1CD
#
#  Directory of C:\Users\HP\Basic_Python\Advance Python
#
# 04-04-2026  11:02    <DIR>          .
# 04-04-2026  11:02    <DIR>          ..
# 03-04-2026  09:55    <DIR>          .ipynb_checkpoints
# 02-04-2026  10:08    <DIR>          __pycache__
# 27-03-2026  10:51            28,630 18_day_Oop_26march.ipynb
# 27-03-2026  15:27            13,254 19_day_oop_27march.ipynb
# 31-03-2026  12:21            26,864 20_day_filehandline_30march.ipynb
# 02-04-2026  09:55             1,288 21_1_02apr_modules.ipynb
# 02-04-2026  10:45             4,027 22_day_2_02apr.ipynb
# 02-04-2026  10:39             5,315 22_exception_handling_02apr.ipynb
# 03-04-2026  09:44             5,313 23_exception handling_logging_3apr.ipynb
# 04-04-2026  11:02             8,161 23_exception_handling_logging_3apr.ipynb
# 31-03-2026  08:16               336 Agentic_AI.txt
# 31-03-2026  11:14                 0 base.py
# 31-03-2026  11:11                70 formula.py
# 02-04-2026  10:46               385 function.py
# 02-04-2026  10:07               105 New Text Document.txt
# 31-03-2026  10:49               114 test.txt
# 03-04-2026  09:55             1,639 vowels.ipynb
#               15 File(s)         95,501 bytes
#                4 Dir(s)  47,460,917,248 bytes free
