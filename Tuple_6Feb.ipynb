# %%
t = (1,2,3)

# %%
t
# Out:
# (1, 2, 3)

# %%
t[1] =20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 t[1] =20
#
# TypeError: 'int' object does not support item assignment

# %%
y = (1,1,2,3,1)

# %%
y.count(1)
# Out:
# 3

# %%
y =(10,20,7,40)

# %%
y.index(7)
# Out:
# 2

# %%
u = (10,20,(50,60),90)

# %%
u[2][1]
# Out:
# 60

# %%
### Sets

# %%
set([1,2,2,3,4,4,4])
# Out:
# {1, 2, 3, 4}

# %%
s = {10,20,30}

# %%
s.add(100)

# %%
s
# Out:
# {10, 20, 30, 100}

# %%
s.remove(20)

# %%
s
# Out:
# {10, 30, 100}

# %%
s1 = {1,2}
s2 = {3,4}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4}

# %%
s1.intersection(s2)
# Out:
# set()

# %%
### Dictionary

# %%
d = {'name':'sham','age':20}

# %%
d['age']
# Out:
# 20

# %%
d['city'] = 'mumbai'

# %%
d['age'] = 21

# %%
d
# Out:
# {'name': 'sham', 'age': 21, 'city': 'mumbai'}
