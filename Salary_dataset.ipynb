# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Salary_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
    
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# 21          21              7.2   98274.0
# 22          22              8.0  101303.0
# 23          23              8.3  113813.0
# 24          24              8.8  109432.0
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
df.tail()
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
sns.boxplot(df['Salary'])
# Out:
# <Axes: ylabel='Salary'>

# %%
plt.boxplot(df['Salary'])
q1  = df.price.quantile(0.25)
q3  = df.price.quantile(0.75)
IQR = q3 - q1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7764\2152077445.py in ?()
#       1 plt.boxplot(df['Salary'])
# ----> 2 q1  = df.price.quantile(0.25)
#       3 q3  = df.price.quantile(0.75)
#       4 IQR = q3 - q1
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'price'

# %%
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# 21          21              7.2   98274.0
# 22          22              8.0  101303.0
# 23          23              8.3  113813.0
# 24          24              8.8  109432.0
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
df.corr()
# Out:
#                  Unnamed: 0  YearsExperience    Salary
# Unnamed: 0         1.000000         0.986460  0.960826
# YearsExperience    0.986460         1.000000  0.978242
# Salary             0.960826         0.978242  1.000000

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
X = df.iloc[:, 1:]

# %%
X
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
y = df['Salary']

# %%
y
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
df.shape
# Out:
# (30, 3)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y, test_size=0.20, random_state=42)

# %%
X_train.shape
# Out:
# (24, 2)

# %%
X_train
# Out:
#     YearsExperience    Salary
# 28             10.4  122392.0
# 24              8.8  109432.0
# 12              4.1   56958.0
# 0               1.2   39344.0
# 4               2.3   39892.0
# 16              5.2   66030.0
# 5               3.0   56643.0
# 13              4.2   57082.0
# 11              4.1   55795.0
# 22              8.0  101303.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 25              9.1  105583.0
# 3               2.1   43526.0
# 21              7.2   98274.0
# 26              9.6  116970.0
# 18              6.0   81364.0
# 29             10.6  121873.0
# 20              6.9   91739.0
# 7               3.3   54446.0
# 10              4.0   63219.0
# 14              4.6   61112.0
# 19              6.1   93941.0
# 6               3.1   60151.0

# %%
y_train
# Out:
# 28    122392.0
# 24    109432.0
# 12     56958.0
# 0      39344.0
# 4      39892.0
# 16     66030.0
# 5      56643.0
# 13     57082.0
# 11     55795.0
# 22    101303.0
# 1      46206.0
# 2      37732.0
# 25    105583.0
# 3      43526.0
# 21     98274.0
# 26    116970.0
# 18     81364.0
# 29    121873.0
# 20     91739.0
# 7      54446.0
# 10     63219.0
# 14     61112.0
# 19     93941.0
# 6      60151.0
# Name: Salary, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
X_train_scaled = scalar.fit_transform(X_train)

# %%
        X_train_scaled
# Out:
# array([[ 1.77445774,  1.74286179],
#        [ 1.21912622,  1.27408   ],
#        [-0.41216011, -0.62397985],
#        [-1.41869849, -1.26110349],
#        [-1.03690807, -1.24128155],
#        [-0.03036969, -0.2958326 ],
#        [-0.79395053, -0.63537385],
#        [-0.37745189, -0.61949459],
#        [-0.41216011, -0.66604723],
#        [ 0.94146047,  0.98004241],
#        [-1.34928205, -1.01289511],
#        [-1.27986561, -1.31941185],
#        [ 1.32325088,  1.13485615],
#        [-1.10632451, -1.10983456],
#        [ 0.66379471,  0.87047913],
#        [ 1.49679198,  1.54674027],
#        [ 0.24729607,  0.25882018],
#        [ 1.84387418,  1.72408881],
#        [ 0.55967005,  0.63409881],
#        [-0.68982587, -0.71484249],
#        [-0.44686833, -0.3975105 ],
#        [-0.23861901, -0.47372371],
#        [ 0.28200429,  0.71374831],
#        [-0.75924231, -0.50848446]])

# %%
X_test_scaled = scalar.transform(X_test)

# %%
X_test_scaled
# Out:
# array([[ 1.5315002 ,  1.38997327],
#        [-0.09978613, -0.22678133],
#        [ 1.04558513,  1.43254705],
#        [ 0.03904675,  0.3212159 ],
#        [-0.68982587, -0.35312815],
#        [-0.51628477, -0.61558808]])

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([112636.,  67939., 113813.,  83089.,  64446.,  57190.])

# %%
y_test
# Out:
# 27    112636.0
# 15     67939.0
# 23    113813.0
# 17     83089.0
# 8      64446.0
# 9      57190.0
# Name: Salary, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 3.2646061508759494e-22

# %%
r2 = r2_score(y_test, y_pred)

# %%
r2
# Out:
# 1.0

# %%
np.sqrt(mse)
# Out:
# np.float64(1.806822113788723e-11)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test,y_pred)
plt.xlabel('Actual Salary')
plt.ylabel('Pred Salary')
plt.title('Actual vs pred')
plt.show()
