# %% [markdown]
# # Data Types in Python

# %% [markdown]
# # Int Data Type

# %%
5
# Out:
# 5

# %%
type (5)
# Out:
# int

# %%
type(123)
# Out:
# int

# %% [markdown]
# # Float :-Numbers in Decimal format

# %%
type(1.3)
# Out:
# float

# %%
type(5.009)
# Out:
# float

# %%
type(999)
# Out:
# int

# %% [markdown]
# # Complex Number : Vector Values

# %%
type(5 + 11j)
# Out:
# complex

# %%
type(9 + 1j)
# Out:
# complex

# %% [markdown]
# # String: Words,Sentences,Letters

# %%
'Hello'
# Out:
# 'Hello'

# %%
"Python"
# Out:
# 'Python'

# %%
print('Welcome')
# Out:
# Welcome

# %%
print("5")
# Out:
# 5

# %%
type(print("hello"))
# Out:
# hello
# NoneType

# %%
""" Hi , Python Online Class
DATA TYPES:Int,Float,Complex Numbers,String,Boolean Numbers
FUNCTIONS:..... """
# Out:
# ' Hi , Python Online Class\nDATA TYPES:Int,Float,Complex Numbers,String,Boolean Numbers\nFUNCTIONS:..... '

# %%
print(""" Hi , Python Online Class
DATA TYPES:Int,Float,Complex Numbers,String,Boolean Numbers
FUNCTIONS:..... """)
# Out:
#  Hi , Python Online Class
# DATA TYPES:Int,Float,Complex Numbers,String,Boolean Numbers
# FUNCTIONS:.....

# %% [markdown]
# # Boolean Number (True or False)

# %%
5 > 2
# Out:
# True

# %%
7 < 6
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool
