# %%
first_name = 'Archana' #str

# %%
last_name ='Gurav' #str

# %%
print(first_name + last_name)
# Out:
# ArchanaGurav

# %%
print(first_name + ' ' + last_name)
# Out:
# Archana Gurav

# %%
marks = 98

# %%
print (first_name + marks) # str + int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print (first_name + marks) # str + int
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(first_name , marks)
# Out:
# Archana 98

# %%
print('My name is '+ first_name)
# Out:
# My name is Archana

# %%
print('My name is '+ first_name + 'I got above marks' + marks)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print('My name is '+ first_name + 'I got above marks' + marks)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('My name is '+ first_name + 'I got above marks' , marks)
# Out:
# My name is ArchanaI got above marks 98

# %%
#f formating
print(f'My name is {first_name} and I got {marks} marks')
# Out:
# My name is Archana and I got 98 marks

# %%
Profession = 'Teacher'
Work = 'Teaching'
Salary = 80000

# %%
print(f'My Profession is {Profession} and my work is to teach the students {Work} and i got salary {Salary}')
# Out:
# My Profession is Teacher and my work is to teach the students Teaching and i got salary 80000

# %%
# How to take input from user
name = input('Write your full name')
print(name)
# Out:
# Write your full name archana guarv
# archana guarv

# %%
name = input('Write your full name:-')
print(f'My full name is {name}')
# Out:
# Write your full name:- Archana Gurav
# My full name is Archana Gurav
