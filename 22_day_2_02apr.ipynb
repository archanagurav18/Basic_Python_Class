# %%
from function import summation

# %%
summation(10,20,30,40,50)
# Out:
# 150

# %%
from function import division
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from function import division
#
# ImportError: cannot import name 'division' from 'function' (C:\Users\HP\Basic_Python\Advance Python\function.py)

# %%
from function import multiply
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from function import multiply
#
# ImportError: cannot import name 'multiply' from 'function' (C:\Users\HP\Basic_Python\Advance Python\function.py)
