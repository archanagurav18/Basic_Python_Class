# %%
import pandas as pd

# %%
df= pd.read_csv('data/Diamond Price Prediction.csv')

# %%
df.head(5)
# Out:
#    Carat(Weight of Daimond) Cut(Quality) Color Clarity  Depth  Table  \
# 0                      0.23        Ideal     E     SI2   61.5   55.0
# 1                      0.21      Premium     E     SI1   59.8   61.0
# 2                      0.23         Good     E     VS1   56.9   65.0
# 3                      0.29      Premium     I     VS2   62.4   58.0
# 4                      0.31         Good     J     SI2   63.3   58.0
#
#    Price(in US dollars)  X(length)  Y(width)  Z(Depth)
# 0                   326       3.95      3.98      2.43
# 1                   326       3.89      3.84      2.31
# 2                   327       4.05      4.07      2.31
# 3                   334       4.20      4.23      2.63
# 4                   335       4.34      4.35      2.75

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Carat(Weight of Daimond)  53940 non-null  float64
#  1   Cut(Quality)              53940 non-null  str
#  2   Color                     53940 non-null  str
#  3   Clarity                   53940 non-null  str
#  4   Depth                     53940 non-null  float64
#  5   Table                     53940 non-null  float64
#  6   Price(in US dollars)      53940 non-null  int64
#  7   X(length)                 53940 non-null  float64
#  8   Y(width)                  53940 non-null  float64
#  9   Z(Depth)                  53940 non-null  float64
# dtypes: float64(6), int64(1), str(3)
# memory usage: 4.1 MB

# %%
df.isnull().sum()
# Out:
# Carat(Weight of Daimond)    0
# Cut(Quality)                0
# Color                       0
# Clarity                     0
# Depth                       0
# Table                       0
# Price(in US dollars)        0
# X(length)                   0
# Y(width)                    0
# Z(Depth)                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(146)

# %%
df[df.duplicated()]
# Out:
#        Carat(Weight of Daimond) Cut(Quality) Color Clarity  Depth  Table  \
# 1005                       0.79        Ideal     G     SI1   62.3   57.0
# 1006                       0.79        Ideal     G     SI1   62.3   57.0
# 1007                       0.79        Ideal     G     SI1   62.3   57.0
# 1008                       0.79        Ideal     G     SI1   62.3   57.0
# 2025                       1.52         Good     E      I1   57.3   58.0
# ...                         ...          ...   ...     ...    ...    ...
# 47969                      0.52        Ideal     D     VS2   61.8   55.0
# 49326                      0.51        Ideal     F    VVS2   61.2   56.0
# 49557                      0.71         Good     F     SI2   64.1   60.0
# 50079                      0.51        Ideal     F    VVS2   61.2   56.0
# 52861                      0.50         Fair     E     VS2   79.0   73.0
#
#        Price(in US dollars)  X(length)  Y(width)  Z(Depth)
# 1005                   2898       5.90      5.85      3.66
# 1006                   2898       5.90      5.85      3.66
# 1007                   2898       5.90      5.85      3.66
# 1008                   2898       5.90      5.85      3.66
# 2025                   3105       7.53      7.42      4.28
# ...                     ...        ...       ...       ...
# 47969                  1919       5.19      5.16      3.20
# 49326                  2093       5.17      5.19      3.17
# 49557                  2130       0.00      0.00      0.00
# 50079                  2203       5.19      5.17      3.17
# 52861                  2579       5.21      5.18      4.09
#
# [146 rows x 10 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.dtypes
# Out:
# Carat(Weight of Daimond)    float64
# Cut(Quality)                    str
# Color                           str
# Clarity                         str
# Depth                       float64
# Table                       float64
# Price(in US dollars)          int64
# X(length)                   float64
# Y(width)                    float64
# Z(Depth)                    float64
# dtype: object

# %%
df.dtypes[df.dtypes=='str']
# Out:
# Cut(Quality)    str
# Color           str
# Clarity         str
# dtype: object

# %%
df.dtypes[df.dtypes=='str'].index
# Out:
# Index(['Cut(Quality)', 'Color', 'Clarity'], dtype='str')

# %%
cat_col=df.dtypes[df.dtypes=='str'].index

# %%
cat_col
# Out:
# Index(['Cut(Quality)', 'Color', 'Clarity'], dtype='str')

# %%
le = LabelEncoder()

# %%
df['Cut(Quality)']=le.fit_transform(df['Cut(Quality)'])

# %%
df['Cut(Quality)']
# Out:
# 0        2
# 1        3
# 2        1
# 3        3
# 4        1
#         ..
# 53935    2
# 53936    1
# 53937    4
# 53938    3
# 53939    2
# Name: Cut(Quality), Length: 53794, dtype: int64

# %%
df['Color']=le.fit_transform(df['Color'])

# %%
df['Color']
# Out:
# 0        1
# 1        1
# 2        1
# 3        5
# 4        6
#         ..
# 53935    0
# 53936    0
# 53937    0
# 53938    4
# 53939    0
# Name: Color, Length: 53794, dtype: int64

# %%
df['Clarity']=le.fit_transform(df['Clarity'])

# %%
df['Clarity']
# Out:
# 0        3
# 1        2
# 2        4
# 3        5
# 4        3
#         ..
# 53935    2
# 53936    2
# 53937    2
# 53938    3
# 53939    3
# Name: Clarity, Length: 53794, dtype: int64

# %%
df.head(5)
# Out:
#    Carat(Weight of Daimond)  Cut(Quality)  Color  Clarity  Depth  Table  \
# 0                      0.23             2      1        3   61.5   55.0
# 1                      0.21             3      1        2   59.8   61.0
# 2                      0.23             1      1        4   56.9   65.0
# 3                      0.29             3      5        5   62.4   58.0
# 4                      0.31             1      6        3   63.3   58.0
#
#    Price(in US dollars)  X(length)  Y(width)  Z(Depth)
# 0                   326       3.95      3.98      2.43
# 1                   326       3.89      3.84      2.31
# 2                   327       4.05      4.07      2.31
# 3                   334       4.20      4.23      2.63
# 4                   335       4.34      4.35      2.75

# %%
df.corr()
# Out:
#                           Carat(Weight of Daimond)  Cut(Quality)     Color  \
# Carat(Weight of Daimond)                  1.000000      0.017785  0.291019
# Cut(Quality)                              0.017785      1.000000  0.000393
# Color                                     0.291019      0.000393  1.000000
# Clarity                                  -0.214068      0.028141 -0.028002
# Depth                                     0.027861     -0.193184  0.047572
# Table                                     0.181091      0.150366  0.026102
# Price(in US dollars)                      0.921548      0.040196  0.171825
# X(length)                                 0.975380      0.022592  0.269876
# Y(width)                                  0.951908      0.027805  0.263153
# Z(Depth)                                  0.953542      0.002442  0.267825
#
#                            Clarity     Depth     Table  Price(in US dollars)  \
# Carat(Weight of Daimond) -0.214068  0.027861  0.181091              0.921548
# Cut(Quality)              0.028141 -0.193184  0.150366              0.040196
# Color                    -0.028002  0.047572  0.026102              0.171825
# Clarity                   1.000000 -0.053165 -0.088074             -0.071218
# Depth                    -0.053165  1.000000 -0.297669             -0.011048
# Table                    -0.088074 -0.297669  1.000000              0.126566
# Price(in US dollars)     -0.071218 -0.011048  0.126566              1.000000
# X(length)                -0.225575 -0.025348  0.194855              0.884504
# Y(width)                 -0.217459 -0.029389  0.183231              0.865395
# Z(Depth)                 -0.224117  0.094757  0.150270              0.861208
#
#                           X(length)  Y(width)  Z(Depth)
# Carat(Weight of Daimond)   0.975380  0.951908  0.953542
# Cut(Quality)               0.022592  0.027805  0.002442
# Color                      0.269876  0.263153  0.267825
# Clarity                   -0.225575 -0.217459 -0.224117
# Depth                     -0.025348 -0.029389  0.094757
# Table                      0.194855  0.183231  0.150270
# Price(in US dollars)       0.884504  0.865395  0.861208
# X(length)                  1.000000  0.974592  0.970686
# Y(width)                   0.974592  1.000000  0.951844
# Z(Depth)                   0.970686  0.951844  1.000000

# %%
X = df.drop('Price(in US dollars)',axis=1)

# %%
X.head(1)
# Out:
#    Carat(Weight of Daimond)  Cut(Quality)  Color  Clarity  Depth  Table  \
# 0                      0.23             2      1        3   61.5   55.0
#
#    X(length)  Y(width)  Z(Depth)
# 0       3.95      3.98      2.43

# %%
y = df['Price(in US dollars)']

# %%
y
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: Price(in US dollars), Length: 53794, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test , y_train, y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
scaler= StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.94345735, -0.54238513, -1.52418638, ..., -1.1223499 ,
#         -1.04690326, -1.07495192],
#        [ 2.96422154, -0.54238513, -1.52418638, ...,  2.33490736,
#          2.23305697,  2.3538824 ],
#        [-0.56529488, -0.54238513, -0.93667968, ..., -0.43800849,
#         -0.37876321, -0.5441282 ],
#        ...,
#        [-1.00648443, -0.54238513,  2.00085384, ..., -1.19345031,
#         -1.14235183, -1.17537803],
#        [ 0.2120391 ,  0.43196552,  2.00085384, ...,  0.35298353,
#          0.25466826,  0.40274655],
#        [ 0.44313838,  0.43196552,  0.23833373, ...,  0.5573972 ,
#          0.49762828,  0.61794536]], shape=(43035, 9))

# %%
X_test = scaler.transform(X_test)

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8869892348179883

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,10))
plt.scatter(y_test,y_pred)
plt.xlabel('Actual Price ')
plt.ylabel('Pred Price')
plt.title('Actual vs pred')
plt.show()
