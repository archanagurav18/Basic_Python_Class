# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Walmart_Sales.csv')

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
sns.boxplot(df['Weekly_Sales'])
# Out:
# <Axes: ylabel='Weekly_Sales'>

# %%
plt.boxplot(df['Weekly_Sales'])
q1  = df.Weekly_Sales.quantile(0.25)
q3  = df.Weekly_Sales.quantile(0.75)
IQR = q3 - q1

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
df.corr
# Out:
# <bound method DataFrame.corr of       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]>

# %%
df1=df.drop('Date',axis=1)

# %%
df1
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment
# 0            8.106
# 1            8.106
# 2            8.106
# 3            8.106
# 4            8.106
# ...            ...
# 6430         8.684
# 6431         8.667
# 6432         8.667
# 6433         8.667
# 6434         8.667
#
# [6435 rows x 7 columns]

# %%
sns.heatmap(df1.corr(), annot=True)
# Out:
# <Axes: >

# %%
X = df1.iloc[:, 1:]

# %%
X
# Out:
#       Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0       1643690.90             0        42.31       2.572  211.096358
# 1       1641957.44             1        38.51       2.548  211.242170
# 2       1611968.17             0        39.93       2.514  211.289143
# 3       1409727.59             0        46.63       2.561  211.319643
# 4       1554806.68             0        46.50       2.625  211.350143
# ...            ...           ...          ...         ...         ...
# 6430     713173.95             0        64.88       3.997  192.013558
# 6431     733455.07             0        64.89       3.985  192.170412
# 6432     734464.36             0        54.47       4.000  192.327265
# 6433     718125.53             0        56.47       3.969  192.330854
# 6434     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment
# 0            8.106
# 1            8.106
# 2            8.106
# 3            8.106
# 4            8.106
# ...            ...
# 6430         8.684
# 6431         8.667
# 6432         8.667
# 6433         8.667
# 6434         8.667
#
# [6435 rows x 6 columns]

# %%
y = df1['Weekly_Sales']

# %%
y
# Out:
# 0       1643690.90
# 1       1641957.44
# 2       1611968.17
# 3       1409727.59
# 4       1554806.68
#            ...
# 6430     713173.95
# 6431     733455.07
# 6432     734464.36
# 6433     718125.53
# 6434     760281.43
# Name: Weekly_Sales, Length: 6435, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y, test_size=0.20, random_state=42)

# %%
X_train.shape
# Out:
# (5148, 6)

# %%
X_train
# Out:
#       Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 1033     836707.85             0        75.32       2.582  214.878556
# 915      558963.83             0        20.70       3.372  192.058484
# 5903     588592.61             0        61.24       3.130  126.546161
# 2083     605413.17             0        69.19       3.906  136.213613
# 5943     526641.23             0        87.40       3.743  129.240581
# ...            ...           ...          ...         ...         ...
# 3772    1709365.19             0        39.32       3.420  137.251185
# 5191     508213.14             0        54.44       2.708  210.376263
# 5226     510787.46             0        86.71       3.684  214.297294
# 5390     342667.35             1        44.64       3.428  130.071032
# 860      506760.54             0        27.28       2.550  189.534100
#
#       Unemployment
# 1033         6.315
# 915          8.818
# 5903         9.003
# 2083         7.806
# 5943         8.257
# ...            ...
# 3772         7.827
# 5191         8.476
# 5226         8.177
# 5390        12.890
# 860          9.014
#
# [5148 rows x 6 columns]

# %%
y_train
# Out:
# 1033     836707.85
# 915      558963.83
# 5903     588592.61
# 2083     605413.17
# 5943     526641.23
#            ...
# 3772    1709365.19
# 5191     508213.14
# 5226     510787.46
# 5390     342667.35
# 860      506760.54
# Name: Weekly_Sales, Length: 5148, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
X_train_scaled = scalar.fit_transform(X_train)

# %%
X_train_scaled
# Out:
# array([[-0.3696424 , -0.26842748,  0.8057783 , -1.71088305,  1.10380441,
#         -0.8978744 ],
#        [-0.86254497, -0.26842748, -2.15108453,  0.01856676,  0.52254808,
#          0.43847483],
#        [-0.80996381, -0.26842748,  0.04355515, -0.51121407, -1.14613429,
#          0.53724615],
#        ...,
#        [-0.94804188, -0.26842748,  1.42237786,  0.70158997,  1.08899892,
#          0.09624556],
#        [-1.24639874,  3.72540101, -0.85508863,  0.14116067, -1.05635133,
#          2.61251161],
#        [-0.95518831, -0.26842748, -1.79487513, -1.78093671,  0.4582488 ,
#          0.54311904]], shape=(5148, 6))

# %%
X_test_scaled = scalar.transform(X_test)

# %%
X_test_scaled
# Out:
# array([[ 0.1664705 , -0.26842748, -0.97689275, -1.22269659, -1.01271986,
#          0.64349205],
#        [ 0.46115423, -0.26842748,  0.45714783,  1.31455952, -0.92404756,
#          0.11493203],
#        [ 1.28538949, -0.26842748,  0.29420097,  0.01856676,  1.1661231 ,
#         -0.29670411],
#        ...,
#        [-0.27384305, -0.26842748, -1.79325108, -1.2686693 ,  0.26306471,
#          0.53137326],
#        [ 1.81227236, -0.26842748,  0.15344954, -1.41096581,  0.99176471,
#          0.10852524],
#        [-0.40614641, -0.26842748, -1.9610701 , -0.29229637, -1.10235965,
#         -0.60369604]], shape=(1287, 6))

# %%
X_test_scaled
# Out:
# array([[ 0.1664705 , -0.26842748, -0.97689275, -1.22269659, -1.01271986,
#          0.64349205],
#        [ 0.46115423, -0.26842748,  0.45714783,  1.31455952, -0.92404756,
#          0.11493203],
#        [ 1.28538949, -0.26842748,  0.29420097,  0.01856676,  1.1661231 ,
#         -0.29670411],
#        ...,
#        [-0.27384305, -0.26842748, -1.79325108, -1.2686693 ,  0.26306471,
#          0.53137326],
#        [ 1.81227236, -0.26842748,  0.15344954, -1.41096581,  0.99176471,
#          0.10852524],
#        [-0.40614641, -0.26842748, -1.9610701 , -0.29229637, -1.10235965,
#         -0.60369604]], shape=(1287, 6))

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([1138800.32, 1304850.67, 1769296.25, ...,  890689.51, 2066187.72,
#         816138.33], shape=(1287,))

# %%
y_test
# Out:
# 2436    1138800.32
# 3361    1304850.67
# 233     1769296.25
# 3667    1077640.13
# 5011     428851.99
#            ...
# 2600    1492060.89
# 6308     801098.43
# 6292     890689.51
# 151     2066187.72
# 2344     816138.33
# Name: Weekly_Sales, Length: 1287, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 2.412365629266443e-19

# %%
r2 = r2_score(y_test, y_pred)

# %%
r2
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test,y_pred)
plt.xlabel('Actual Weekly_Sales')
plt.ylabel('Pred Weekly_Sales')
plt.title('Actual vs pred')
plt.show()
