# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('CAR DETAILs.csv')

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
sns.boxplot(df['selling_price'])
# Out:
# <Axes: ylabel='selling_price'>

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df1 = df.drop('name',axis=1)

# %% [markdown]
# #

# %%
df1
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2007          60000      70000  Petrol  Individual       Manual
# 1     2007         135000      50000  Petrol  Individual       Manual
# 2     2012         600000     100000  Diesel  Individual       Manual
# 3     2017         250000      46000  Petrol  Individual       Manual
# 4     2014         450000     141000  Diesel  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 4335  2014         409999      80000  Diesel  Individual       Manual
# 4336  2014         409999      80000  Diesel  Individual       Manual
# 4337  2009         110000      83000  Petrol  Individual       Manual
# 4338  2016         865000      90000  Diesel  Individual       Manual
# 4339  2016         225000      40000  Petrol  Individual       Manual
#
#              owner
# 0      First Owner
# 1      First Owner
# 2      First Owner
# 3      First Owner
# 4     Second Owner
# ...

# %%
df1.corr
# Out:
# <bound method DataFrame.corr of       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2007          60000      70000  Petrol  Individual       Manual
# 1     2007         135000      50000  Petrol  Individual       Manual
# 2     2012         600000     100000  Diesel  Individual       Manual
# 3     2017         250000      46000  Petrol  Individual       Manual
# 4     2014         450000     141000  Diesel  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 4335  2014         409999      80000  Diesel  Individual       Manual
# 4336  2014         409999      80000  Diesel  Individual       Manual
# 4337  2009         110000      83000  Petrol  Individual       Manual
# 4338  2016         865000      90000  Diesel  Individual       Manual
# 4339  2016         225000      40000  Petrol  Individual       Manual
#
#              owner
# 0      First Owner
# 1      First Owner
# 2      First Owner
# ...

# %%
df1['fuel'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
map_fuel={'Petrol':1, 'Diesel':2, 'CNG':3, 'LPG':4, 'Electric':5}

# %%
df1['fuel'] = df1['fuel'].map(map_fuel)

# %%
df1
# Out:
#       year  selling_price  km_driven  fuel seller_type transmission  \
# 0     2007          60000      70000     1  Individual       Manual
# 1     2007         135000      50000     1  Individual       Manual
# 2     2012         600000     100000     2  Individual       Manual
# 3     2017         250000      46000     1  Individual       Manual
# 4     2014         450000     141000     2  Individual       Manual
# ...    ...            ...        ...   ...         ...          ...
# 4335  2014         409999      80000     2  Individual       Manual
# 4336  2014         409999      80000     2  Individual       Manual
# 4337  2009         110000      83000     1  Individual       Manual
# 4338  2016         865000      90000     2  Individual       Manual
# 4339  2016         225000      40000     1  Individual       Manual
#
#              owner
# 0      First Owner
# 1      First Owner
# 2      First Owner
# 3      First Owner
# 4     Second Owner
# ...            ...
# ...

# %%
df1['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
map_seller_type = {'Individual':1, 'Dealer':2, 'Trustmark Dealer':3}

# %%
df1['seller_type'] = df1['seller_type'].map(map_seller_type)

# %%
df1
# Out:
#       year  selling_price  km_driven  fuel  seller_type transmission  \
# 0     2007          60000      70000     1            1       Manual
# 1     2007         135000      50000     1            1       Manual
# 2     2012         600000     100000     2            1       Manual
# 3     2017         250000      46000     1            1       Manual
# 4     2014         450000     141000     2            1       Manual
# ...    ...            ...        ...   ...          ...          ...
# 4335  2014         409999      80000     2            1       Manual
# 4336  2014         409999      80000     2            1       Manual
# 4337  2009         110000      83000     1            1       Manual
# 4338  2016         865000      90000     2            1       Manual
# 4339  2016         225000      40000     1            1       Manual
#
#              owner
# 0      First Owner
# 1      First Owner
# 2      First Owner
# 3      First Owner
# 4     Second Owner
# ...

# %%
df1['transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
map_transmission = {'Manual':1, 'Automatic':2}

# %%
df1['transmission'] = df1['transmission'].map(map_transmission)

# %%
df1
# Out:
#       year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0     2007          60000      70000     1            1             1
# 1     2007         135000      50000     1            1             1
# 2     2012         600000     100000     2            1             1
# 3     2017         250000      46000     1            1             1
# 4     2014         450000     141000     2            1             1
# ...    ...            ...        ...   ...          ...           ...
# 4335  2014         409999      80000     2            1             1
# 4336  2014         409999      80000     2            1             1
# 4337  2009         110000      83000     1            1             1
# 4338  2016         865000      90000     2            1             1
# 4339  2016         225000      40000     1            1             1
#
#              owner
# 0      First Owner
# 1      First Owner
# 2      First Owner
# 3      First Owner
# 4     Second Owner
# ...

# %%
df1['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Fourth & Above Owner',
#        'Third Owner', 'Test Drive Car'], dtype=object)

# %%
map_owner = {'First Owner':1, 'Second Owner':2, 'Fourth & Above Owner':3,
       'Third Owner':4, 'Test Drive Car':5}

# %%
df1['owner'] = df1['owner'].map(map_owner)

# %%
df1
# Out:
#       year  selling_price  km_driven  fuel  seller_type  transmission  owner
# 0     2007          60000      70000     1            1             1      1
# 1     2007         135000      50000     1            1             1      1
# 2     2012         600000     100000     2            1             1      1
# 3     2017         250000      46000     1            1             1      1
# 4     2014         450000     141000     2            1             1      2
# ...    ...            ...        ...   ...          ...           ...    ...
# 4335  2014         409999      80000     2            1             1      2
# 4336  2014         409999      80000     2            1             1      2
# 4337  2009         110000      83000     1            1             1      2
# 4338  2016         865000      90000     2            1             1      1
# 4339  2016         225000      40000     1            1             1      1
#
# [4340 rows x 7 columns]

# %%
df1.corr()
# Out:
#                    year  selling_price  km_driven      fuel  seller_type  \
# year           1.000000       0.413922  -0.419688  0.090388     0.182458
# selling_price  0.413922       1.000000  -0.192289  0.226883     0.240666
# km_driven     -0.419688      -0.192289   1.000000  0.274760    -0.187131
# fuel           0.090388       0.226883   0.274760  1.000000     0.011358
# seller_type    0.182458       0.240666  -0.187131  0.011358     1.000000
# transmission   0.143800       0.530205  -0.120226  0.027507     0.200191
# owner         -0.392591      -0.189919   0.275937  0.015234    -0.209072
#
#                transmission     owner
# year               0.143800 -0.392591
# selling_price      0.530205 -0.189919
# km_driven         -0.120226  0.275937
# fuel               0.027507  0.015234
# seller_type        0.200191 -0.209072
# transmission       1.000000 -0.075035
# owner             -0.075035  1.000000

# %%
sns.heatmap(df1.corr(), annot=True)
# Out:
# <Axes: >

# %%
X = df1.iloc[:, 1:]

# %%
X
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner
# 0             60000      70000     1            1             1      1
# 1            135000      50000     1            1             1      1
# 2            600000     100000     2            1             1      1
# 3            250000      46000     1            1             1      1
# 4            450000     141000     2            1             1      2
# ...             ...        ...   ...          ...           ...    ...
# 4335         409999      80000     2            1             1      2
# 4336         409999      80000     2            1             1      2
# 4337         110000      83000     1            1             1      2
# 4338         865000      90000     2            1             1      1
# 4339         225000      40000     1            1             1      1
#
# [4340 rows x 6 columns]

# %%
y = df1['selling_price']

# %%
y
# Out:
# 0        60000
# 1       135000
# 2       600000
# 3       250000
# 4       450000
#          ...
# 4335    409999
# 4336    409999
# 4337    110000
# 4338    865000
# 4339    225000
# Name: selling_price, Length: 4340, dtype: int64

# %%
df1.shape
# Out:
# (4340, 7)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y, test_size=0.20, random_state=42)

# %%
X_train.shape
# Out:
# (3472, 6)

# %%
X_train
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner
# 227         1500000      20000     2            1             1      1
# 964          500000      50000     2            1             1      1
# 2045          92800      25000     1            1             1      2
# 1025          95000      70000     2            1             1      1
# 4242         685000      72000     2            2             1      1
# ...             ...        ...   ...          ...           ...    ...
# 3444         500000      50000     2            1             1      1
# 466          133000      80000     2            1             1      1
# 3092         665000      51000     2            2             1      1
# 3772         250999      80000     2            1             1      1
# 860          175000      80000     1            1             1      1
#
# [3472 rows x 6 columns]

# %%
y_train
# Out:
# 227     1500000
# 964      500000
# 2045      92800
# 1025      95000
# 4242     685000
#          ...
# 3444     500000
# 466      133000
# 3092     665000
# 3772     250999
# 860      175000
# Name: selling_price, Length: 3472, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
X_train_scaled = scalar.fit_transform(X_train)

# %%
X_train_scaled
# Out:
# array([[ 1.69682306, -0.98114024,  0.85176567, -0.5549349 , -0.3416984 ,
#         -0.59788168],
#        [-0.0132832 , -0.34146273,  0.85176567, -0.5549349 , -0.3416984 ,
#         -0.59788168],
#        [-0.70963847, -0.87452732, -0.96254746, -0.5549349 , -0.3416984 ,
#          0.54457577],
#        ...,
#        [ 0.26888434, -0.32014015,  0.85176567,  1.46682163, -0.3416984 ,
#         -0.59788168],
#        [-0.43910137,  0.29821478,  0.85176567, -0.5549349 , -0.3416984 ,
#         -0.59788168],
#        [-0.56906773,  0.29821478, -0.96254746, -0.5549349 , -0.3416984 ,
#         -0.59788168]], shape=(3472, 6))

# %%
X_test_scaled = scalar.transform(X_test)

# %%
X_test_scaled
# Out:
# array([[-0.58616879,  0.29821478,  0.85176567, -0.5549349 , -0.3416984 ,
#         -0.59788168],
#        [-0.44080976, -0.83188215, -0.96254746, -0.5549349 , -0.3416984 ,
#         -0.59788168],
#        [-0.66312358, -0.51794975, -0.96254746, -0.5549349 , -0.3416984 ,
#          0.54457577],
#        ...,
#        [-0.61182039, -0.55468857,  0.85176567, -0.5549349 , -0.3416984 ,
#          0.54457577],
#        [ 0.24323274, -1.26942157, -0.96254746,  3.48857817, -0.3416984 ,
#         -0.59788168],
#        [ 0.11497477, -0.7679144 , -0.96254746,  1.46682163, -0.3416984 ,
#         -0.59788168]], shape=(868, 6))

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([ 165000.        ,  250000.        ,  120000.        ,
#         450000.        ,  730000.        ,  155000.        ,
#         530000.        ,   92800.        ,  284000.        ,
#         260000.        ,  511000.        , 1800000.        ,
#         320000.        ,   90000.        ,  850000.        ,
#         500000.        ,  624000.        ,  750000.        ,
#         125000.        ,  675000.        ,  500000.        ,
#        1500000.        ,  200000.        ,  700000.        ,
#         175000.        ,  630000.        ,  750000.        ,
#         210000.        ,  500000.        ,  650000.        ,
#         250000.        ,  290000.        ,  450000.        ,
#         750000.        ,  550000.        ,  160000.        ,
#         650000.        ,  655000.        ,  135000.        ,
#         360000.        ,  625000.        ,  360000.        ,
#         600000.        ,  300000.        ,  140000.        ,
# ...

# %%
y_test
# Out:
# 3978    165000
# 1448    250000
# 2664    120000
# 17      450000
# 1634    730000
#          ...
# 3468    130000
# 3164    350000
# 416     150000
# 1616    650000
# 2480    575000
# Name: selling_price, Length: 868, dtype: int64

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 2.6729090736574635e-18

# %%
r2 = r2_score(y_test, y_pred)

# %%
r2
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test,y_pred)
plt.xlabel('actual_selling_price')
plt.ylabel('pred_selling_price')
plt.title('Actual vs pred')
plt.show()
