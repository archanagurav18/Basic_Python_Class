# %%
L = ['a','b',['c',['d','e','target'],'f'],'g']

# %%
L [2][1][2]
# Out:
# 'target'

# %%
D = ['red','blue']

# %%
D.append(['yellow','green'])

# %%
D
# Out:
# ['red', 'blue', ['yellow', 'green']]

# %%
D.extend(['green','yellow'])

# %%
D
# Out:
# ['red', 'blue', ['yellow', 'green'], 'green', 'yellow']

# %%
M = [[1,2,3],[4,5,6],[7,8,9]]

# %%
M[1][2]
# Out:
# 6

# %%
N = [10,20,40]

# %%
N.insert(2,30)

# %%
N
# Out:
# [10, 20, 30, 40]

# %%
Mixed =[1,'python',['true', 'false']]

# %%
Mixed[2][1]
# Out:
# 'false'

# %%
### nested list ###

# %%
Nested = [1,[2,3,[4,5,6]],7]

# %%
Nested
# Out:
# [1, [2, 3, [4, 5, 6]], 7]

# %%
Nested[1][1]
# Out:
# 3

# %%
Nested[1][2]
# Out:
# [4, 5, 6]

# %%
Nested[2]
# Out:
# 7

# %%
Matrix =[[10,20,30],[40,50,60],[70,80,90]]

# %%
Matrix[1]
# Out:
# [40, 50, 60]

# %%
Matrix[2]
# Out:
# [70, 80, 90]

# %%
Matrix[2][2]
# Out:
# 90

# %%
####

# %%
F =(['kiwi','mango'])

# %%
F
# Out:
# ['kiwi', 'mango']

# %%
F.append(['apple','banana'])

# %%
F
# Out:
# ['kiwi', 'mango', ['apple', 'banana']]

# %%
F.extend(['apple','banana'])

# %%
F
# Out:
# ['kiwi', 'mango', ['apple', 'banana'], 'apple', 'banana']

# %%
Num =[10,20,40,50]

# %%
Num.insert(2,30)

# %%
Num
# Out:
# [10, 20, 30, 40, 50]

# %%
list = [5,6,[7,8,9],10]

# %%
list[2][1]
# Out:
# 8

# %%
data = [1,2]

# %%
data.extend([3,[4,5]])

# %%
data
# Out:
# [1, 2, 3, [4, 5]]

# %%
Y = [10,[20,'hello']]

# %%
Y[1][1]
# Out:
# 'hello'

# %%
Y[1][1] = 'hi'

# %%
Y
# Out:
# [10, [20, 'hi']]
