# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('student_exam_data.csv')

# %%
df.head()
# Out:
#    study_hours  exam_score
# 0          4.4          59
# 1          9.6          98
# 2          7.6          82
# 3          6.4          69
# 4          2.4          42

# %%
df.tail()
# Out:
#      study_hours  exam_score
# 495          4.2          55
# 496          6.3          69
# 497          1.7          44
# 498          9.8          95
# 499          9.9          99

# %%
df.head(15)
# Out:
#     study_hours  exam_score
# 0           4.4          59
# 1           9.6          98
# 2           7.6          82
# 3           6.4          69
# 4           2.4          42
# 5           2.4          47
# 6           1.5          35
# 7           8.8          92
# 8           6.4          75
# 9           7.4          76
# 10          1.2          32
# 11          9.7          97
# 12          8.5          84
# 13          2.9          52
# 14          2.6          42

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   study_hours  500 non-null    float64
#  1   exam_score   500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB

# %%
df.isnull().sum()
# Out:
# study_hours    0
# exam_score     0
# dtype: int64

# %%
sns.boxplot(df['exam_score'])
# Out:
# <Axes: ylabel='exam_score'>

# %%
df.corr()
# Out:
#              study_hours  exam_score
# study_hours      1.00000     0.98577
# exam_score       0.98577     1.00000

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    study_hours  exam_score
# 0          4.4          59
# 1          9.6          98
# 2          7.6          82
# 3          6.4          69
# 4          2.4          42

# %%
X = df.iloc[:, 1:]

# %%
X
# Out:
#      exam_score
# 0            59
# 1            98
# 2            82
# 3            69
# 4            42
# ..          ...
# 495          55
# 496          69
# 497          44
# 498          95
# 499          99
#
# [500 rows x 1 columns]

# %%
y = df['exam_score']

# %%
y
# Out:
# 0      59
# 1      98
# 2      82
# 3      69
# 4      42
#        ..
# 495    55
# 496    69
# 497    44
# 498    95
# 499    99
# Name: exam_score, Length: 500, dtype: int64

# %%
df.shape
# Out:
# (500, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y, test_size=0.20, random_state=42)

# %%
X_train.shape
# Out:
# (400, 1)

# %%
X_train
# Out:
#      exam_score
# 249          81
# 433          45
# 19           55
# 322          68
# 332          36
# ..          ...
# 106          60
# 270          83
# 348          61
# 435          81
# 102          59
#
# [400 rows x 1 columns]

# %%
y_train
# Out:
# 249    81
# 433    45
# 19     55
# 322    68
# 332    36
#        ..
# 106    60
# 270    83
# 348    61
# 435    81
# 102    59
# Name: exam_score, Length: 400, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
X_train_scaled = scalar.fit_transform(X_train)

# %%
X_train_scaled
# Out:
# array([[ 0.86236496],
#        [-1.13571314],
#        [-0.58069145],
#        [ 0.14083676],
#        [-1.63523267],
#        [-1.69073484],
#        [ 0.02983242],
#        [ 0.4183476 ],
#        [ 0.86236496],
#        [-1.24671748],
#        [ 0.75136062],
#        [-0.19217626],
#        [-1.80173918],
#        [ 0.75136062],
#        [ 1.41738665],
#        [-0.3031806 ],
#        [ 1.41738665],
#        [-1.35772182],
#        [-0.91370447],
#        [-1.35772182],
#        [ 0.36284543],
#        [ 0.75136062],
#        [-0.08117192],
#        [-0.13667409],
#        [ 0.08533459],
#        [-0.58069145],
#        [-0.63619362],
#        [ 1.13987581],
#        [ 0.9733693 ],
#        [-0.63619362],
#        [-1.08021097],
#        [ 0.75136062],
#        [-1.74623701],
#        [ 0.9733693 ],
#        [ 1.25088014],
#        [-1.0247088 ],
#        [ 1.02887147],
#        [-0.02566975],
#        [ 0.08533459],
#        [ 0.9733693 ],
#        [-1.35772182],
#        [-1.46872616],
#        [-0.02566975],
#        [ 0.80686279],
#        [-0.80270013],
#        [ 0.58485411],
#        [-0.35868277],
#        [-1.63523267],
#        [ 1.58389316],
#        [ 0.02983242],
#        [-1.0247088 ],
#        [ 0.75136062],
#        [ 0.19633892],
#        [-0.63619362],
#        [ 0.69585845],
#        [ 0.30734326],
#        [ 0.19633892],
#        [ 0.52935194],
#        [ 1.30638231],
#        [-0.3031806 ],
#        [-0.8582023 ],
#        [-1.41322399],
#        [-0.3031806 ],
#        [-1.63523267],
#        [ 0.9733693 ],
#        [ 1.58389316],
#        [-1.24671748],
#        [ 1.47288882],
#        [ 1.30638231],
#        [-0.63619362],
#        [-1.13571314],
#        [ 1.08437364],
#        [ 1.52839099],
#        [ 1.13987581],
#        [ 0.58485411],
#        [-0.69169579],
#        [ 0.69585845],
#        [-1.46872616],
#        [-0.58069145],
#        [-0.96920663],
#        [ 1.47288882],
#        [-0.58069145],
#        [-0.52518928],
#        [-0.08117192],
#        [-1.30221965],
#        [-0.80270013],
#        [-0.58069145],
#        [ 1.02887147],
#        [ 0.08533459],
#        [-1.41322399],
#        [-0.80270013],
#        [-0.58069145],
#        [-1.19121531],
#        [ 1.19537798],
#        [-1.30221965],
#        [ 1.36188448],
#        [-1.80173918],
#        [ 1.30638231],
#        [-1.0247088 ],
#        [ 1.47288882],
#        [ 1.36188448],
#        [-1.52422833],
#        [ 1.63939533],
#        [ 1.02887147],
#        [-0.02566975],
#        [ 0.91786713],
#        [ 1.63939533],
#        [ 0.9733693 ],
#        [ 1.41738665],
#        [ 1.52839099],
#        [-0.52518928],
#        [ 0.02983242],
#        [-0.13667409],
#        [-1.24671748],
#        [ 0.47384977],
#        [-1.74623701],
#        [ 0.9733693 ],
#        [-0.8582023 ],
#        [-0.91370447],
#        [-1.13571314],
#        [ 0.30734326],
#        [-0.08117192],
#        [-0.69169579],
#        [ 0.80686279],
#        [ 1.19537798],
#        [ 1.25088014],
#        [-1.85724135],
#        [-1.13571314],
#        [-0.19217626],
#        [-0.46968711],
#        [-1.13571314],
#        [-0.13667409],
#        [-1.0247088 ],
#        [-1.69073484],
#        [-0.35868277],
#        [ 0.47384977],
#        [-0.08117192],
#        [-1.30221965],
#        [ 1.19537798],
#        [-0.41418494],
#        [ 0.9733693 ],
#        [-0.80270013],
#        [-1.30221965],
#        [-1.85724135],
#        [-1.24671748],
#        [ 0.19633892],
#        [ 0.52935194],
#        [ 0.69585845],
#        [ 0.9733693 ],
#        [-0.96920663],
#        [ 1.41738665],
#        [ 0.75136062],
#        [ 0.08533459],
#        [ 1.30638231],
#        [-0.8582023 ],
#        [-0.69169579],
#        [ 0.36284543],
#        [-0.46968711],
#        [-0.19217626],
#        [ 0.69585845],
#        [ 0.08533459],
#        [-1.41322399],
#        [-1.13571314],
#        [-0.19217626],
#        [-0.80270013],
#        [-1.13571314],
#        [-0.46968711],
#        [-0.24767843],
#        [-1.80173918],
#        [-0.58069145],
#        [ 1.13987581],
#        [-0.96920663],
#        [-0.24767843],
#        [ 1.75039967],
#        [ 0.19633892],
#        [ 1.30638231],
#        [-0.63619362],
#        [ 1.19537798],
#        [ 0.47384977],
#        [-0.24767843],
#        [ 0.25184109],
#        [-0.19217626],
#        [ 0.47384977],
#        [ 1.41738665],
#        [ 0.14083676],
#        [ 0.9733693 ],
#        [ 0.14083676],
#        [ 0.75136062],
#        [ 1.52839099],
#        [-1.24671748],
#        [ 0.25184109],
#        [-1.13571314],
#        [ 1.19537798],
#        [-0.02566975],
#        [ 1.25088014],
#        [-1.24671748],
#        [-0.46968711],
#        [ 0.4183476 ],
#        [-0.8582023 ],
#        [ 0.69585845],
#        [-1.13571314],
#        [-0.02566975],
#        [-1.5797305 ],
#        [-1.35772182],
#        [-0.02566975],
#        [ 1.63939533],
#        [ 0.14083676],
#        [ 0.30734326],
#        [ 1.47288882],
#        [ 0.91786713],
#        [ 0.47384977],
#        [-0.63619362],
#        [-0.02566975],
#        [-0.13667409],
#        [ 0.9733693 ],
#        [-1.85724135],
#        [ 1.58389316],
#        [ 0.69585845],
#        [-1.24671748],
#        [ 0.75136062],
#        [-0.41418494],
#        [-0.08117192],
#        [-1.0247088 ],
#        [-1.19121531],
#        [ 0.30734326],
#        [-1.19121531],
#        [-0.96920663],
#        [ 1.30638231],
#        [ 1.08437364],
#        [ 1.52839099],
#        [ 0.64035628],
#        [ 1.02887147],
#        [ 1.30638231],
#        [ 0.30734326],
#        [ 0.47384977],
#        [ 0.02983242],
#        [ 0.91786713],
#        [-1.13571314],
#        [-0.02566975],
#        [-0.19217626],
#        [ 0.64035628],
#        [ 1.25088014],
#        [ 0.25184109],
#        [ 1.19537798],
#        [ 1.58389316],
#        [ 0.08533459],
#        [ 1.63939533],
#        [ 0.86236496],
#        [-1.24671748],
#        [-0.8582023 ],
#        [-1.13571314],
#        [ 1.47288882],
#        [-1.30221965],
#        [ 1.36188448],
#        [-0.41418494],
#        [-1.63523267],
#        [ 1.58389316],
#        [-1.46872616],
#        [-0.8582023 ],
#        [-1.69073484],
#        [-1.69073484],
#        [ 1.19537798],
#        [-1.0247088 ],
#        [-0.91370447],
#        [ 0.19633892],
#        [-1.24671748],
#        [ 0.47384977],
#        [ 0.4183476 ],
#        [ 0.36284543],
#        [ 1.41738665],
#        [ 0.25184109],
#        [-1.46872616],
#        [ 0.9733693 ],
#        [-0.08117192],
#        [-0.91370447],
#        [ 0.47384977],
#        [ 0.08533459],
#        [-0.58069145],
#        [ 0.9733693 ],
#        [-0.52518928],
#        [-1.69073484],
#        [-1.13571314],
#        [ 0.52935194],
#        [ 0.08533459],
#        [ 0.19633892],
#        [-0.74719796],
#        [-1.46872616],
#        [-1.30221965],
#        [ 0.64035628],
#        [-1.41322399],
#        [-0.8582023 ],
#        [-0.69169579],
#        [ 0.75136062],
#        [-0.46968711],
#        [ 0.9733693 ],
#        [-1.41322399],
#        [-1.13571314],
#        [ 0.75136062],
#        [-0.41418494],
#        [ 0.58485411],
#        [ 0.4183476 ],
#        [-0.13667409],
#        [-0.08117192],
#        [-0.35868277],
#        [ 1.47288882],
#        [-1.74623701],
#        [ 0.47384977],
#        [ 0.02983242],
#        [-0.69169579],
#        [-1.46872616],
#        [ 0.36284543],
#        [ 1.02887147],
#        [ 1.02887147],
#        [ 1.36188448],
#        [-1.30221965],
#        [-0.80270013],
#        [-1.35772182],
#        [-0.58069145],
#        [ 1.25088014],
#        [ 0.75136062],
#        [ 1.80590184],
#        [ 1.47288882],
#        [-0.02566975],
#        [-1.0247088 ],
#        [ 0.75136062],
#        [ 1.30638231],
#        [-1.69073484],
#        [ 1.86140401],
#        [ 0.19633892],
#        [ 1.30638231],
#        [ 1.36188448],
#        [ 0.75136062],
#        [-1.35772182],
#        [ 1.36188448],
#        [ 1.13987581],
#        [ 0.19633892],
#        [ 1.52839099],
#        [ 1.47288882],
#        [-0.74719796],
#        [ 0.80686279],
#        [ 1.52839099],
#        [-0.91370447],
#        [ 1.30638231],
#        [-0.41418494],
#        [-0.24767843],
#        [-0.74719796],
#        [ 1.13987581],
#        [-0.13667409],
#        [ 0.47384977],
#        [-0.69169579],
#        [-0.24767843],
#        [ 0.36284543],
#        [-0.08117192],
#        [ 1.75039967],
#        [-1.80173918],
#        [ 0.52935194],
#        [ 1.25088014],
#        [-1.19121531],
#        [ 0.19633892],
#        [ 0.14083676],
#        [ 0.19633892],
#        [-1.69073484],
#        [ 0.36284543],
#        [-0.3031806 ],
#        [ 0.80686279],
#        [ 0.91786713],
#        [-1.19121531],
#        [ 1.47288882],
#        [-1.13571314],
#        [-0.35868277],
#        [ 0.9733693 ],
#        [-0.46968711],
#        [ 1.41738665],
#        [ 0.86236496],
#        [-0.24767843],
#        [ 0.25184109],
#        [-0.35868277],
#        [ 0.36284543],
#        [ 1.08437364],
#        [-0.74719796],
#        [-0.19217626],
#        [-0.91370447],
#        [ 0.14083676],
#        [-1.52422833],
#        [-1.46872616],
#        [ 0.64035628],
#        [-1.41322399],
#        [-0.46968711],
#        [ 0.80686279],
#        [-0.80270013],
#        [ 1.13987581],
#        [ 1.86140401],
#        [ 0.19633892],
#        [ 0.25184109],
#        [-1.13571314],
#        [-0.3031806 ],
#        [ 0.9733693 ],
#        [-0.24767843],
#        [ 0.86236496],
#        [-0.35868277]])

# %%
X_test_scaled = scalar.transform(X_test)

# %%
X_test_scaled
# Out:
# array([[ 0.30734326],
#        [ 0.80686279],
#        [-1.52422833],
#        [-1.0247088 ],
#        [ 1.30638231],
#        [-0.46968711],
#        [-1.5797305 ],
#        [-0.8582023 ],
#        [-1.46872616],
#        [ 1.13987581],
#        [ 0.58485411],
#        [-0.46968711],
#        [-0.3031806 ],
#        [-0.69169579],
#        [-1.52422833],
#        [ 0.91786713],
#        [-0.58069145],
#        [ 0.58485411],
#        [-0.41418494],
#        [ 1.08437364],
#        [-0.24767843],
#        [ 0.4183476 ],
#        [ 1.19537798],
#        [-1.69073484],
#        [ 0.75136062],
#        [ 0.86236496],
#        [-1.19121531],
#        [ 0.4183476 ],
#        [ 0.25184109],
#        [-1.41322399],
#        [ 1.30638231],
#        [ 0.91786713],
#        [-1.08021097],
#        [-0.96920663],
#        [ 0.91786713],
#        [-1.30221965],
#        [-1.19121531],
#        [ 0.86236496],
#        [-1.19121531],
#        [-0.63619362],
#        [ 0.86236496],
#        [ 0.4183476 ],
#        [ 1.13987581],
#        [ 0.75136062],
#        [ 1.41738665],
#        [-1.35772182],
#        [-0.35868277],
#        [ 1.75039967],
#        [-0.3031806 ],
#        [-0.69169579],
#        [-1.74623701],
#        [ 1.02887147],
#        [-1.08021097],
#        [-0.58069145],
#        [ 0.58485411],
#        [ 1.36188448],
#        [-1.5797305 ],
#        [-0.3031806 ],
#        [ 0.36284543],
#        [-0.52518928],
#        [ 0.30734326],
#        [-1.19121531],
#        [-0.46968711],
#        [ 0.69585845],
#        [-1.30221965],
#        [ 0.02983242],
#        [ 0.02983242],
#        [-0.69169579],
#        [ 0.69585845],
#        [-0.35868277],
#        [ 0.75136062],
#        [-0.02566975],
#        [ 0.36284543],
#        [-1.69073484],
#        [-1.30221965],
#        [ 0.64035628],
#        [-0.02566975],
#        [ 1.41738665],
#        [ 0.08533459],
#        [-0.52518928],
#        [ 1.6948975 ],
#        [-0.63619362],
#        [ 0.47384977],
#        [ 0.08533459],
#        [ 0.9733693 ],
#        [-1.13571314],
#        [-0.8582023 ],
#        [ 0.58485411],
#        [-1.41322399],
#        [ 0.52935194],
#        [ 0.91786713],
#        [-1.5797305 ],
#        [-0.24767843],
#        [ 1.52839099],
#        [ 1.02887147],
#        [-1.80173918],
#        [ 0.47384977],
#        [ 0.75136062],
#        [ 0.58485411],
#        [-1.13571314]])

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([71., 80., 38., 47., 89., 57., 37., 50., 39., 86., 76., 57., 60.,
#        53., 38., 82., 55., 76., 58., 85., 61., 73., 87., 35., 79., 81.,
#        44., 73., 70., 40., 89., 82., 46., 48., 82., 42., 44., 81., 44.,
#        54., 81., 73., 86., 79., 91., 41., 59., 97., 60., 53., 34., 84.,
#        46., 55., 76., 90., 37., 60., 72., 56., 71., 44., 57., 78., 42.,
#        66., 66., 53., 78., 59., 79., 65., 72., 35., 42., 77., 65., 91.,
#        67., 56., 96., 54., 74., 67., 83., 45., 50., 76., 40., 75., 82.,
#        37., 61., 93., 84., 33., 74., 79., 76., 45.])

# %%
y_test
# Out:
# 361    71
# 73     80
# 374    38
# 155    47
# 104    89
#        ..
# 347    33
# 86     74
# 75     79
# 438    76
# 15     45
# Name: exam_score, Length: 100, dtype: int64

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 5.553580772755923e-30

# %%
r2 = r2_score(y_test, y_pred)

# %%
r2
# Out:
# 1.0

# %%
np.sqrt(mse)
# Out:
# np.float64(2.3566036520288944e-15)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test,y_pred)
plt.xlabel('actual_exam_score')
plt.ylabel('pred_exam_score')
plt.title('Actual vs pred')
plt.show()
